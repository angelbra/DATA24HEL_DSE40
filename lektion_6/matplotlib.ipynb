# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Genera data
# `np.linspace(start, stop, n)` returnerar `n` värden mellan `start`och `stop`.
#
# NumPys `array` har stöd för vektoriserade operationer. Operationen `y = x**3` resulterar i en ny `array` med varje värde i `x` upphöjt till 3.

# %%
x = np.linspace(-1, 1, 100)
y = x**3

# %%
x
# Out:
# array([-1.        , -0.97979798, -0.95959596, -0.93939394, -0.91919192,
#        -0.8989899 , -0.87878788, -0.85858586, -0.83838384, -0.81818182,
#        -0.7979798 , -0.77777778, -0.75757576, -0.73737374, -0.71717172,
#        -0.6969697 , -0.67676768, -0.65656566, -0.63636364, -0.61616162,
#        -0.5959596 , -0.57575758, -0.55555556, -0.53535354, -0.51515152,
#        -0.49494949, -0.47474747, -0.45454545, -0.43434343, -0.41414141,
#        -0.39393939, -0.37373737, -0.35353535, -0.33333333, -0.31313131,
#        -0.29292929, -0.27272727, -0.25252525, -0.23232323, -0.21212121,
#        -0.19191919, -0.17171717, -0.15151515, -0.13131313, -0.11111111,
#        -0.09090909, -0.07070707, -0.05050505, -0.03030303, -0.01010101,
#         0.01010101,  0.03030303,  0.05050505,  0.07070707,  0.09090909,
#         0.11111111,  0.13131313,  0.15151515,  0.17171717,  0.19191919,
#         0.21212121,  0.23232323,  0.25252525,  0.27272727,  0.29292929,
#         0.31313131,  0.33333333,  0.35353535,  0.37373737,  0.39393939,
#         0.41414141,  0.43434343,  0.45454545,  0.47474747,  0.49494949,
#         0.51515152,  0.53535354,  0.55555556,  0.57575758,  0.5959596 ,
#         0.61616162,  0.63636364,  0.65656566,  0.67676768,  0.6969697 ,
#         0.71717172,  0.73737374,  0.75757576,  0.77777778,  0.7979798 ,
#         0.81818182,  0.83838384,  0.85858586,  0.87878788,  0.8989899 ,
#         0.91919192,  0.93939394,  0.95959596,  0.97979798,  1.        ])

# %%
y
# Out:
# array([-1.00000000e+00, -9.40610059e-01, -8.83619379e-01, -8.28978490e-01,
#        -7.76637923e-01, -7.26548208e-01, -6.78659877e-01, -6.32923460e-01,
#        -5.89289487e-01, -5.47708490e-01, -5.08130999e-01, -4.70507545e-01,
#        -4.34788658e-01, -4.00924870e-01, -3.68866710e-01, -3.38564710e-01,
#        -3.09969401e-01, -2.83031313e-01, -2.57700977e-01, -2.33928923e-01,
#        -2.11665682e-01, -1.90861786e-01, -1.71467764e-01, -1.53434148e-01,
#        -1.36711467e-01, -1.21250254e-01, -1.07001038e-01, -9.39143501e-02,
#        -8.19407214e-02, -7.10306823e-02, -6.11347636e-02, -5.22034960e-02,
#        -4.41874103e-02, -3.70370370e-02, -3.07029070e-02, -2.51355510e-02,
#        -2.02854996e-02, -1.61032836e-02, -1.25394337e-02, -9.54448062e-03,
#        -7.06895503e-03, -5.06338768e-03, -3.47830926e-03, -2.26425050e-03,
#        -1.37174211e-03, -7.51314801e-04, -3.53499282e-04, -1.28826269e-04,
#        -2.78264741e-05, -1.03061015e-06,  1.03061015e-06,  2.78264741e-05,
#         1.28826269e-04,  3.53499282e-04,  7.51314801e-04,  1.37174211e-03,
#         2.26425050e-03,  3.47830926e-03,  5.06338768e-03,  7.06895503e-03,
#         9.54448062e-03,  1.25394337e-02,  1.61032836e-02,  2.02854996e-02,
#         2.51355510e-02,  3.07029070e-02,  3.70370370e-02,  4.41874103e-02,
#         5.22034960e-02,  6.11347636e-02,  7.10306823e-02,  8.19407214e-02,
#         9.39143501e-02,  1.07001038e-01,  1.21250254e-01,  1.36711467e-01,
#         1.53434148e-01,  1.71467764e-01,  1.90861786e-01,  2.11665682e-01,
#         2.33928923e-01,  2.57700977e-01,  2.83031313e-01,  3.09969401e-01,
#         3.38564710e-01,  3.68866710e-01,  4.00924870e-01,  4.34788658e-01,
#         4.70507545e-01,  5.08130999e-01,  5.47708490e-01,  5.89289487e-01,
#         6.32923460e-01,  6.78659877e-01,  7.26548208e-01,  7.76637923e-01,
#         8.28978490e-01,  8.83619379e-01,  9.40610059e-01,  1.00000000e+00])

# %% [markdown]
# ### Plotta data med det explicita gränssnittet
#
# * Skapa en `Figure` och en `Axis` med `plt.subplots()`.
# * Rita ett linjediagram över `x` och `y`.

# %%
fig, ax = plt.subplots()

ax.plot(x, y)

# %% [markdown]
# Vi kan lägga till titel och etiketter.

# %%
fig1, ax = plt.subplots()
ax.plot(x, y)

ax.set(title="$y=x^3$", xlabel="x")
ax.set_ylabel("y", rotation=0)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Flera `Axes`
#
# * Skapa tre olika `y`-serier.
# * Skapa en `Figure` med tre `Axes`-objekt med `plt.subplots()`.
# * Använd funktionen `zip()` för att slå ihop våra `axs`-objekt och våra `y`-serier och plotta en serie på varje `Axes`.

# %%
y2 = x**2
y3 = y.copy()
y4 = x**4

# %%
fig2, axs = plt.subplots(1, 3, figsize=(12, 4), sharey=True)

for ax, data, title in zip(axs, [y2, y3, y4], ["$y=x^2$", "$y=x^3$", "$y=x^4$"]):
    ax.plot(x, data)
    ax.set(title=title)

fig2.suptitle("Lite olika funktioner")
# Out:
# Text(0.5, 0.98, 'Lite olika funktioner')

# %% [markdown]
# ### Punktdiagram med `scatter()`

# %%
y = np.random.random(100)

fig, ax = plt.subplots()
ax.scatter(x, y)

# %% [markdown]
# ### Det implicita gränssnittet
# Fördelar:
# * snabbare att skriva om man ska göra enkla plottar
#
# Nackdelar:
# * mindre kontroll över plotten eftersom vi inte skapar referenser till objekten

# %%
plt.plot(x, y3)
plt.title('$y=x^3$')
plt.xlabel('x')
plt.ylabel('y', rotation=0)
# Out:
# Text(0, 0.5, 'y')
